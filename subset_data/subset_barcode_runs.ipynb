# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#           sample
# 0  COV2-2196_400
# 1  COV2-2130_400
# 2  2196+2130_400

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#             name library   antibody concentration concentration_units    date  \
# 0  2196+2130_400    lib1  2196+2130           400           ng_per_mL  200904
# 1  2196+2130_400    lib2  2196+2130           400           ng_per_mL  200904
# 2  COV2-2130_400    lib1  COV2-2130           400           ng_per_mL  201102
# 3  COV2-2130_400    lib2  COV2-2130           400           ng_per_mL  201102
# 4  COV2-2196_400    lib1  COV2-2196           400           ng_per_mL  201102
# 5  COV2-2196_400    lib2  COV2-2196           400           ng_per_mL  201102
#
#                     pre_sample                   post_sample  frac_escape  \
# 0  expt_24-33-none-0-reference  expt_29-2196+2130-400-escape        0.141
# 1  expt_24-33-none-0-reference  expt_29-2196+2130-400-escape        0.162
# 2  expt_65-67-none-0-reference  expt_66-COV2-2130-400-escape        0.135
# 3  expt_65-67-none-0-reference  expt_66-COV2-2130-400-escape        0.134
# 4  expt_65-67-none-0-reference  expt_65-COV2-2196-400-escape        0.150
# 5  expt_65-67-none-0-reference  expt_65-COV2-2196-400-escape        0.156
#
#    pre_cells_sorted  post_cells_sorted
# 0         1523536.0        160000000.0
# 1         1382411.0        160000000.0
# 2         1933517.0                NaN
# 3         2145467.0                NaN
# 4         2323887.0                NaN
# 5         1828346.0                NaN

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#   library                        sample    date  experiment   antibody  \
# 0    lib1   expt_24-33-none-0-reference  200904  expt_24-33       none
# 1    lib2   expt_24-33-none-0-reference  200904  expt_24-33       none
# 2    lib1   expt_65-67-none-0-reference  201102  expt_65-67       none
# 3    lib2   expt_65-67-none-0-reference  201102  expt_65-67       none
# 4    lib1  expt_29-2196+2130-400-escape  200904     expt_29  2196+2130
# 5    lib2  expt_29-2196+2130-400-escape  200904     expt_29  2196+2130
# 6    lib1  expt_66-COV2-2130-400-escape  201102     expt_66  COV2-2130
# 7    lib2  expt_66-COV2-2130-400-escape  201102     expt_66  COV2-2130
# 8    lib1  expt_65-COV2-2196-400-escape  201102     expt_65  COV2-2196
# 9    lib2  expt_65-COV2-2196-400-escape  201102     expt_65  COV2-2196
#
#   concentration concentration_units           group  selection  frac_escape  \
# 0             0           ng_per_mL  clinical_serum  reference          NaN
# 1             0           ng_per_mL  clinical_serum  reference          NaN
# 2             0           ng_per_mL           Crowe  reference          NaN
# 3             0           ng_per_mL           Crowe  reference          NaN
# 4           400           ng_per_mL  clinical_serum     escape        0.141
# 5           400           ng_per_mL  clinical_serum     escape        0.162
# 6           400           ng_per_mL           Crowe     escape        0.135
# 7           400           ng_per_mL           Crowe     escape        0.134
# 8           400           ng_per_mL           Crowe     escape        0.150
# 9           400           ng_per_mL           Crowe     escape        0.156
#
#    cells_sorted                                                 R1
# 0   160000000.0  /shared/ngs/illumina/agreaney/200914_D00300_10...
# 1   160000000.0  /shared/ngs/illumina/agreaney/200914_D00300_10...
# 2           NaN  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 3           NaN  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 4     1523536.0  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 5     1382411.0  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 6     1933517.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 7     2145467.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 8     2323887.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
# 9     1828346.0  /shared/ngs/illumina/tstarr/201123_D00300_1119...
